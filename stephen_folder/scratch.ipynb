# %%
import pandas as pd
import acquire as a
import prepare as p

# %%
df = pd.read_csv('school_data.csv')

# %%
df = p.clean_df()

# %%
school_ids = df['school_id'].astype(str).str.zfill(9)

# %%
school_ids.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1391 entries, 0 to 1560
# Series name: school_id
# Non-Null Count  Dtype
# --------------  -----
# 1391 non-null   object
# dtypes: object(1)
# memory usage: 21.7+ KB

# %%
school_ids.to_csv('high_school_ids_clean.csv')

# %%
list_school_ids = school_ids.tolist()

# %%
list_school_ids
# Out:
# ['001902001',
#  '001903001',
#  '001904001',
#  '001906002',
#  '001907001',
#  '001908002',
#  '001909001',
#  '002901001',
#  '002901002',
#  '003801001',
#  '003902001',
#  '003903001',
#  '003904001',
#  '003905001',
#  '003907001',
#  '004901001',
#  '005901001',
#  '005902001',
#  '005904001',
#  '007901001',
#  '007902001',
#  '007904001',
#  '007905001',
#  '007906001',
#  '008901001',
#  '008902001',
#  '008903001',
#  '009901001',
#  '010902001',
#  '011901001',
#  '011901002',
#  '011901005',
#  '011901022',
#  '011902001',
#  '011904002',
#  '011905001',
#  '012901001',
#  '013901001',
#  '013905001',
#  '014801001',
#  '014801002',
#  '014801004',
#  '014801005',
#  '014801006',
#  '014801007',
#  '014801008',
#  '014801009',
#  '014801010',
#  '014901001',
#  '014903001',
#  '014903010',
#  '014905001',
#  '014906001',
#  '014906002',
#  '014906006',
#  '014906007',
#  '014906008',
#  '014906013',
#  '014907001',
#  '014908001',
#  '014909002',
#  '014909008',
# ...
